# %% [markdown]
# # AREEB BIN AZIM  ( CS-19090 )
# # MOIZ ALI ( CS-19087 )
# # OMER BIN MUJEEB ( CS-19095 )

# %% [markdown]
# # ________________________________________

# %% [markdown]
# ##  Importing essential libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the dataset

# %%
data = pd.read_csv("The_Grades_Dataset.csv")
data.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
data.head(50)
# Out:
#     Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0   CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1   CS-97002      A      D     D+         D     B-      C      D      A
# 2   CS-97003      A      B      A        B-     B+      A     B-     B+
# 3   CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4   CS-97005     A-     A-     A-        B+      A      A     A-     B+
# 5   CS-97006      A     B-      B        D+     C+     A-     C+      B
# 6   CS-97007     B-     C-     A-         D     A-      B      A     B+
# 7   CS-97008     B+     B+     C+         C      C     A-     C-     A-
# 8   CS-97009     A-      C     A-        D+      B     A-     A-     A-
# 9   CS-97010      A      B     C+         B      B     A-      C     B-
# 10  CS-97011     A-     B-     B+        C-     C-     B-     C+     B-
# 11  CS-97012     A-      C     A-        C+     C-      A     B-     B+
# ...

# %% [markdown]
# ## this is the main step.. all the encoding of the grades takes place here.. we've applied ORDINAL ENCODING TECHNIQUE here :)

# %%
mapping = { "A+":4.0 , "A":4.0 , "A-":3.7 , "B+":3.4 , "B":3.0 , "B-":2.7 , "C+":2.3 , "C": 2.0 , "C-":1.7 , "C-":1.4 , "D+":1.3 , "D":1.0 , "F":0, "WU":0}
for i in data: 
       if i!="Seat No." and i!="CGPA":
        data[i]=data[i].replace(mapping)

# %%
pd.set_option('display.max_columns', None)
# data.head()

# %% [markdown]
# ## Filling the missing values by Fill Forward technique

# %%
df = pd.DataFrame(data)
df.fillna(method='ffill', inplace=True)
# data.head()

# %%
#data["CY-105"] = data["CY-105"].fillna(data["CY-105"].median())
#data.columns[data.isna().any()]
data.head()
# Out:
#    Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0  CS-97001     2.7     1.3     1.4        2.0     1.4     1.3     1.0
# 1  CS-97002     4.0     1.0     1.3        1.0     2.7     2.0     1.0
# 2  CS-97003     4.0     3.0     4.0        2.7     3.4     4.0     2.7
# 3  CS-97004     1.0     2.3     1.3        1.0     1.0     3.7     1.3
# 4  CS-97005     3.7     3.7     3.7        3.4     4.0     4.0     3.7
#
#    EL-102  EE-119  ME-107 CS-107  HS-205/20 MT-222 EE-222 MT-224 CS-210  \
# 0     1.4     2.7     1.4    1.4        3.4      1    3.7    2.7    2.3
# 1     4.0     1.3     1.0    3.4        2.3    2.7    1.4    1.3    1.3
# 2     3.4     3.7     3.7    2.7        3.7      4      4      4      4
# 3     1.4     1.0     2.3      1        3.0    1.3    2.7      1      2
# 4     3.4     4.0     3.7      2        4.0      4    3.7    3.7    3.7
#
#   CS-211 CS-203 CS-214  EE-217  CS-212 CS-215  MT-331  EF-303 HS-304  CS-301  \
# ...

# %% [markdown]
# ## checking if the any column has an EMPTY VALUE or NaN

# %%
data.columns[data.isna().any()]
# Out:
# Index([], dtype='object')

# %%
data.head()
# Out:
#    Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0  CS-97001     2.7     1.3     1.4        2.0     1.4     1.3     1.0
# 1  CS-97002     4.0     1.0     1.3        1.0     2.7     2.0     1.0
# 2  CS-97003     4.0     3.0     4.0        2.7     3.4     4.0     2.7
# 3  CS-97004     1.0     2.3     1.3        1.0     1.0     3.7     1.3
# 4  CS-97005     3.7     3.7     3.7        3.4     4.0     4.0     3.7
#
#    EL-102  EE-119  ME-107 CS-107  HS-205/20 MT-222 EE-222 MT-224 CS-210  \
# 0     1.4     2.7     1.4    1.4        3.4      1    3.7    2.7    2.3
# 1     4.0     1.3     1.0    3.4        2.3    2.7    1.4    1.3    1.3
# 2     3.4     3.7     3.7    2.7        3.7      4      4      4      4
# 3     1.4     1.0     2.3      1        3.0    1.3    2.7      1      2
# 4     3.4     4.0     3.7      2        4.0      4    3.7    3.7    3.7
#
#   CS-211 CS-203 CS-214  EE-217  CS-212 CS-215  MT-331  EF-303 HS-304  CS-301  \
# ...

# %% [markdown]
# ## The removal unwanted columns of dataset (i-e courses of 2nd, 3rd and 4th year) are dropped.. for Model-1

# %%
model1 = data
model1.drop(["Seat No.","HS-205/20", "MT-222", "EE-222" , "MT-224" , "CS-210" , "CS-211" , "CS-203" , "CS-214" , "EE-217" , "CS-212" , "CS-215" , "MT-331" , "EF-303" , "HS-304" , "CS-301" , "CS-302" ,   "TC-383" ,  "MT-442" ,  "EL-332" , "CS-318" ,  "CS-306" ,  "CS-312" ,  "CS-317" ,  "CS-403" , "CS-421" , "CS-406" , "CS-414" , "CS-419" , "CS-423" , "CS-412"],axis=1, inplace=True)

# %%
model1.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.3     1.4        2.0     1.4     1.3     1.0     1.4     2.7
# 1     4.0     1.0     1.3        1.0     2.7     2.0     1.0     4.0     1.3
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
# 3     1.0     2.3     1.3        1.0     1.0     3.7     1.3     1.4     1.0
# 4     3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4     4.0
#
#    ME-107 CS-107   CGPA
# 0     1.4    1.4  2.205
# 1     1.0    3.4  2.008
# 2     3.7    2.7  3.608
# 3     2.3      1  1.906
# 4     3.7      2  3.448

# %%
model1.columns[model1.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# # MODEL-1 ( KNN REGRESSION )

# %%
# Every one line skipped means cell change...(KNN Regression) Model1
y=model1['CGPA'].values
model1.drop(['CGPA'],axis=1,inplace=True)
#model1.drop(['Seat No.'],axis=1,inplace=True)
x=model1.values

# %% [markdown]
# ## Divide the dataset into 75% for training and 25% for testing purpose

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.25 , random_state=25)

# %%
import random
def remove_str(nd_array):
    for i in nd_array:
#         new.append(i)
        for j in range(len(i)):
            if type(i[j])==str:
                y=random.uniform(0.0, 4.0)
                x=float("{0:.3f}". format(y))
                i[j] = x
                
#                 new.pop()
#                 y_arr.pop()
    return nd_array


def rounded(array):
    y_train=[]
    for i in range(len(array)):
        x=float("{0:.3f}". format(array[i]))
        y_train.append(x)
    return y_train

# a=[[1,2,'I'],[2,4,5,6],[2,4,5,6],[2,4,5,6],[2,4,5,'W']]
# print(remove_str(a))

# %%
y_train = rounded(y_train)
y_test = rounded(y_test)
x_train = remove_str(x_train)
x_test = remove_str(x_test)

# %% [markdown]
# ## applying KNN Regression with 5 neighbours* and train that model with the .fit() method

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors=5)
regressor.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# ## this line is actually predict the output.. overall CGPA based on the current data it has (i-e x_test)

# %%
y_pred = regressor.predict(x_test)
# print(y_pred)
# print(y_test)

# %%
y_pred = rounded(y_pred)

# %%
# y_pred

# %%
sample2=[]
for i in range(1,12):
    inp=float(input('Enter GP of Course'))
    sample2.append(inp)
print(sample2)
regressor.predict([sample2])
# Out:
# Enter GP of Course3.3
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.3
# Enter GP of Course3.6
# Enter GP of Course3.5
# Enter GP of Course3.6
# Enter GP of Course3.6
# Enter GP of Course3.2
# [3.3, 3.2, 3.2, 3.2, 3.2, 3.3, 3.6, 3.5, 3.6, 3.6, 3.2]
# array([3.3346])

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ## Showing the accuracy of this model

# %%
accuracy = r2_score(y_test,y_pred)
print("Model Accuracy =", accuracy*100, "in percent")
# Out:
# Model Accuracy = 77.57718131456176 in percent

# %% [markdown]
# ## We use Matplotlib library to show the trend and compare the actual and predicted output :)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %%
# y_pred_df = pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})
# y_pred_df[0:20]

# %% [markdown]
# # MODEL-1 ( MULTIPLE LINEAR REGRESSION )

# %%
# Every one line skipped means cell change...(Multiple Linear Regression) Model1
y=model1['CGPA'].values
model1.drop(['CGPA'],axis=1,inplace=True)
x=model1.values

# %% [markdown]
# ## Divide the dataset into 75% for training and 25% for testing purpose

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.25 , random_state=0)

# %%
y_train = rounded(y_train)
y_test = rounded(y_test)
x_train = remove_str(x_train)
x_test = remove_str(x_test)

# %% [markdown]
# ## Applying Linear Regression model here :)

# %%
from sklearn.linear_model import LinearRegression

# %%
ml = LinearRegression()
ml.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## this line is actually predict the output.. overall CGPA based on the current data it has (i-e x_test)

# %%
y_pred = ml.predict(x_test)
y_pred = rounded(y_pred)

# %%
# print(y_pred)
# print(y_test)

# %%
sample2=[]
for i in range(1,12):
    inp=float(input('Enter GP of Course'))
    sample2.append(inp)
print( sample2)
ml.predict([sample2])
# Out:
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.2
# [3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2]
# array([3.1873215])

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ## Showing the accuracy of this model

# %%
accuracy = r2_score(y_test,y_pred)
print("Model Accuracy =", accuracy*100, "in percent")
# Out:
# Model Accuracy = 83.61901599143502 in percent

# %% [markdown]
# ## We use Matplotlib library to show the trend and compare the actual and predicted output :)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %% [markdown]
# # Model-2

# %% [markdown]
# ## Loading the dataset

# %%
model2 = pd.read_csv("The_Grades_Dataset.csv")
model2.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %% [markdown]
# ## this is the main step.. all the encoding of the grades takes place here.. we've applied ORDINAL ENCODING TECHNIQUE here :)

# %%
mapping = { "A+":4.0 , "A":4.0 , "A-":3.7 , "B+":3.4 , "B":3.0 , "B-":2.7 , "C+":2.3 , "C": 2.0 , "C-":1.7 , "C-":1.4 , "D+":1.3 , "D":1.0 , "F":0, "WU":0}
for i in model2: 
       if i!="Seat No." and i!="CGPA":
        model2[i]=model2[i].replace(mapping)

# %%
pd.set_option('display.max_columns', None)
model2.head(138)
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001     2.7     1.3     1.4        2.0     1.4     1.3     1.0
# 1    CS-97002     4.0     1.0     1.3        1.0     2.7     2.0     1.0
# 2    CS-97003     4.0     3.0     4.0        2.7     3.4     4.0     2.7
# 3    CS-97004     1.0     2.3     1.3        1.0     1.0     3.7     1.3
# 4    CS-97005     3.7     3.7     3.7        3.4     4.0     4.0     3.7
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 133  CS-97134     2.7     1.4     1.4        1.0     1.4     3.7     2.3
# 134  CS-97135     3.7     1.3     3.4        1.0     2.0     3.4     2.3
# 135  CS-97136     3.7     1.3     3.7        1.3     3.0     4.0     2.0
# 136  CS-97137     1.0     1.3     1.4        1.0     1.4     1.4     1.0
# 137  CS-97138     1.4     2.3     0.0        0.0     0.0     3.0     0.0
#
#      EL-102  EE-119  ME-107 CS-107  HS-205/20 MT-222 EE-222 MT-224 CS-210  \
# ...

# %% [markdown]
# ## Filling the missing values by Fill Forward technique

# %%
df = pd.DataFrame(model2)
df.fillna(method='ffill', inplace=True)

# %%
model2.head()
# Out:
#    Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0  CS-97001     2.7     1.3     1.4        2.0     1.4     1.3     1.0
# 1  CS-97002     4.0     1.0     1.3        1.0     2.7     2.0     1.0
# 2  CS-97003     4.0     3.0     4.0        2.7     3.4     4.0     2.7
# 3  CS-97004     1.0     2.3     1.3        1.0     1.0     3.7     1.3
# 4  CS-97005     3.7     3.7     3.7        3.4     4.0     4.0     3.7
#
#    EL-102  EE-119  ME-107 CS-107  HS-205/20 MT-222 EE-222 MT-224 CS-210  \
# 0     1.4     2.7     1.4    1.4        3.4      1    3.7    2.7    2.3
# 1     4.0     1.3     1.0    3.4        2.3    2.7    1.4    1.3    1.3
# 2     3.4     3.7     3.7    2.7        3.7      4      4      4      4
# 3     1.4     1.0     2.3      1        3.0    1.3    2.7      1      2
# 4     3.4     4.0     3.7      2        4.0      4    3.7    3.7    3.7
#
#   CS-211 CS-203 CS-214  EE-217  CS-212 CS-215  MT-331  EF-303 HS-304  CS-301  \
# ...

# %%
model2.columns[model2.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ## The removal unwanted columns of dataset (i-e courses of 3rd and 4th year) are dropped.. for Model-2

# %%
model2.drop([ "MT-331" , "EF-303" , "HS-304" , "CS-301" , "CS-302" ,   "TC-383" ,  "MT-442" ,  "EL-332" , "CS-318" ,  "CS-306" ,  "CS-312" ,  "CS-317" ,  "CS-403" , "CS-421" , "CS-406" , "CS-414" , "CS-419" , "CS-423" , "CS-412"],axis=1, inplace=True)

# %%
model2.head()
# Out:
#    Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0  CS-97001     2.7     1.3     1.4        2.0     1.4     1.3     1.0
# 1  CS-97002     4.0     1.0     1.3        1.0     2.7     2.0     1.0
# 2  CS-97003     4.0     3.0     4.0        2.7     3.4     4.0     2.7
# 3  CS-97004     1.0     2.3     1.3        1.0     1.0     3.7     1.3
# 4  CS-97005     3.7     3.7     3.7        3.4     4.0     4.0     3.7
#
#    EL-102  EE-119  ME-107 CS-107  HS-205/20 MT-222 EE-222 MT-224 CS-210  \
# 0     1.4     2.7     1.4    1.4        3.4      1    3.7    2.7    2.3
# 1     4.0     1.3     1.0    3.4        2.3    2.7    1.4    1.3    1.3
# 2     3.4     3.7     3.7    2.7        3.7      4      4      4      4
# 3     1.4     1.0     2.3      1        3.0    1.3    2.7      1      2
# 4     3.4     4.0     3.7      2        4.0      4    3.7    3.7    3.7
#
#   CS-211 CS-203 CS-214  EE-217  CS-212 CS-215   CGPA
# ...

# %%
import random
def remove_str(nd_array):
    for i in nd_array:
#         new.append(i)
        for j in range(len(i)):
            if type(i[j])==str:
                y=random.uniform(0.0, 4.0)
                x=float("{0:.3f}". format(y))
                i[j] = x
                
#                 new.pop()
#                 y_arr.pop()
    return nd_array


def rounded(array):
    y_train=[]
    for i in range(len(array)):
        x=float("{0:.3f}". format(array[i]))
        y_train.append(x)
    return y_train

# a=[[1,2,'I'],[2,4,5,6],[2,4,5,6],[2,4,5,6],[2,4,5,'W']]
# print(remove_str(a))

# %% [markdown]
# # MODEL-2 ( KNN REGRESSION )

# %%
# Every one line skipped means cell change...(KNN Regression) Model2
y=model2['CGPA'].values
model2.drop(['CGPA'],axis=1,inplace=True)
#model2.drop(['Seat No.'],axis=1,inplace=True)
x=model2.values

# %% [markdown]
# ## Divide the dataset into 75% for training and 25% for testing purpose

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.25 , random_state=25)

# %%
y_train = rounded(y_train)
y_test = rounded(y_test)
x_train = remove_str(x_train)
x_test = remove_str(x_test)

# %%
# # Every one line skipped means cell change...(KNN Regression) Model2
# y=model2['CGPA'].values
# model2.drop(['CGPA'],axis=1,inplace=True)
# #model2.drop(['Seat No.'],axis=1,inplace=True)
# x=model2.values

# %% [markdown]
# ## applying KNN Regression with 5 neighbours* and train that model with the .fit() method

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors=5)
regressor.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# ## this line is actually predict the output.. overall CGPA based on the current data it has (i-e x_test)

# %%
y_pred = regressor.predict(x_test)
# print(y_pred)
# print(y_test)

# %%
y_pred = rounded(y_pred)

# %%
# y_pred

# %% [markdown]
# ## testing case.. taking inputs (i-e courses GPs) and return CGPA based on that GPs

# %%
sample2=[]
for i in range(1,24):
    inp=float(input('Enter GP of Course'))
    sample2.append(inp)
print(sample2)
regressor.predict([sample2])
# Out:
# Enter GP of Course3.3
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.3
# Enter GP of Course3.2
# Enter GP of Course3.2
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.6
# Enter GP of Course3.6
# Enter GP of Course3.5
# Enter GP of Course3.2
# Enter GP of Course3.1
# Enter GP of Course3.0
# Enter GP of Course3.2
# Enter GP of Course2.3
# Enter GP of Course2.3
# Enter GP of Course3.6
# Enter GP of Course3.2
# Enter GP of Course3.5
# Enter GP of Course3.9
# Enter GP of Course3.4
# Enter GP of Course3.8
# [3.3, 3.2, 3.2, 3.3, 3.2, 3.2, 3.3, 3.3, 3.6, 3.6, 3.5, 3.2, 3.1, 3.0, 3.2, 2.3, 2.3, 3.6, 3.2, 3.5, 3.9, 3.4, 3.8]
# array([3.3192])

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ## Calculating the accuracy of the model

# %%
accuracy = r2_score(y_test,y_pred)
print("Model Accuracy =", accuracy*100, "in percent")
# Out:
# Model Accuracy = 85.81809248693652 in percent

# %% [markdown]
# ## We use Matplotlib library to show the trend and compare the actual and predicted output :)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %% [markdown]
# # MODEL-2 ( MULTIPLE LINEAR REGRESSION )

# %%
y=model2['CGPA'].values
model2.drop(['CGPA'],axis=1,inplace=True)
#model2.drop(['Seat No.'],axis=1,inplace=True)
x=model2.values

# %% [markdown]
# ## Divide the dataset into 75% for training and 25% for testing purpose

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.25 , random_state=0)

# %%
y_train = rounded(y_train)
y_test = rounded(y_test)
x_train = remove_str(x_train)
x_test = remove_str(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## applying Linear Regression model here

# %%
ml = LinearRegression()
ml.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## this line is actually predict the output.. overall CGPA based on the current data it has (i-e x_test)

# %%
y_pred = ml.predict(x_test)
# print(y_pred)
# print(y_test)

# %%
y_pred = rounded(y_pred)

# %%
# y_pred

# %%
sample2=[]
for i in range(1,24):
    inp=float(input('Enter GP of Course'))
    sample2.append(inp)
print(sample2)
ml.predict([sample2])
# Out:
# Enter GP of Course2.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.3
# Enter GP of Course3.5
# Enter GP of Course3.6
# Enter GP of Course3.1
# Enter GP of Course3.1
# Enter GP of Course3.0
# Enter GP of Course3.0
# Enter GP of Course3.0
# [2.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.5, 3.6, 3.1, 3.1, 3.0, 3.0, 3.0]
# array([3.26534323])

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ## calculating the accuracy of this model

# %%
accuracy = r2_score(y_test,y_pred)
print("Model Accuracy =", accuracy*100, "in percent")
# Out:
# Model Accuracy = 90.73627914724204 in percent

# %% [markdown]
# ## We use Matplotlib library to show the trend and compare the actual and predicted output :)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %% [markdown]
# # Model-3

# %% [markdown]
# ## Loading the Dataset and display it over here

# %%
model3 = pd.read_csv("The_Grades_Dataset.csv")
model3.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#   ME-107 CS-107 HS-205/20 MT-222 EE-222 MT-224 CS-210 CS-211 CS-203 CS-214  \
# 0     C-     C-        B+      D     A-     B-     C+     D+     D+      D
# 1      D     B+        C+     B-     C-     D+     D+      D      C      D
# 2     A-     B-        A-      A      A      A      A     A+      A     A-
# 3     C+      D         B     D+     B-      D      C     B+     C+      D
# 4     A-      C         A      A     A-     A-     A-     B-      A     A-
#
# ...

# %% [markdown]
# ## this is the main step.. all the encoding of the grades takes place here.. we've applied ORDINAL ENCODING TECHNIQUE here :)

# %%
mapping = { "A+":4.0 , "A":4.0 , "A-":3.7 , "B+":3.4 , "B":3.0 , "B-":2.7 , "C+":2.3 , "C": 2.0 , "C-":1.7 , "C-":1.4 , "D+":1.3 , "D":1.0 , "F":0, "WU":0}
for i in model3: 
       if i!="Seat No." and i!="CGPA":
        model3[i]=model3[i].replace(mapping)

# %%
pd.set_option('display.max_columns', None)
model3.head(138)
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001     2.7     1.3     1.4        2.0     1.4     1.3     1.0
# 1    CS-97002     4.0     1.0     1.3        1.0     2.7     2.0     1.0
# 2    CS-97003     4.0     3.0     4.0        2.7     3.4     4.0     2.7
# 3    CS-97004     1.0     2.3     1.3        1.0     1.0     3.7     1.3
# 4    CS-97005     3.7     3.7     3.7        3.4     4.0     4.0     3.7
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 133  CS-97134     2.7     1.4     1.4        1.0     1.4     3.7     2.3
# 134  CS-97135     3.7     1.3     3.4        1.0     2.0     3.4     2.3
# 135  CS-97136     3.7     1.3     3.7        1.3     3.0     4.0     2.0
# 136  CS-97137     1.0     1.3     1.4        1.0     1.4     1.4     1.0
# 137  CS-97138     1.4     2.3     0.0        0.0     0.0     3.0     0.0
#
#      EL-102  EE-119  ME-107 CS-107  HS-205/20 MT-222 EE-222 MT-224 CS-210  \
# ...

# %% [markdown]
# ## Filling the missing values by Fill Forward technique

# %%
df = pd.DataFrame(model3)
df.fillna(method='ffill', inplace=True)
model3.head()
# Out:
#    Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0  CS-97001     2.7     1.3     1.4        2.0     1.4     1.3     1.0
# 1  CS-97002     4.0     1.0     1.3        1.0     2.7     2.0     1.0
# 2  CS-97003     4.0     3.0     4.0        2.7     3.4     4.0     2.7
# 3  CS-97004     1.0     2.3     1.3        1.0     1.0     3.7     1.3
# 4  CS-97005     3.7     3.7     3.7        3.4     4.0     4.0     3.7
#
#    EL-102  EE-119  ME-107 CS-107  HS-205/20 MT-222 EE-222 MT-224 CS-210  \
# 0     1.4     2.7     1.4    1.4        3.4      1    3.7    2.7    2.3
# 1     4.0     1.3     1.0    3.4        2.3    2.7    1.4    1.3    1.3
# 2     3.4     3.7     3.7    2.7        3.7      4      4      4      4
# 3     1.4     1.0     2.3      1        3.0    1.3    2.7      1      2
# 4     3.4     4.0     3.7      2        4.0      4    3.7    3.7    3.7
#
#   CS-211 CS-203 CS-214  EE-217  CS-212 CS-215  MT-331  EF-303 HS-304  CS-301  \
# ...

# %%
model3.columns[model3.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ## The removal unwanted columns of dataset (i-e courses of Final Year) are dropped.. for Model-3

# %%
model3.drop(["CS-403" , "CS-421" , "CS-406" , "CS-414" , "CS-419" , "CS-423" , "CS-412"],axis=1, inplace=True)

# %%
model3.head()
# Out:
#    Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0  CS-97001     2.7     1.3     1.4        2.0     1.4     1.3     1.0
# 1  CS-97002     4.0     1.0     1.3        1.0     2.7     2.0     1.0
# 2  CS-97003     4.0     3.0     4.0        2.7     3.4     4.0     2.7
# 3  CS-97004     1.0     2.3     1.3        1.0     1.0     3.7     1.3
# 4  CS-97005     3.7     3.7     3.7        3.4     4.0     4.0     3.7
#
#    EL-102  EE-119  ME-107 CS-107  HS-205/20 MT-222 EE-222 MT-224 CS-210  \
# 0     1.4     2.7     1.4    1.4        3.4      1    3.7    2.7    2.3
# 1     4.0     1.3     1.0    3.4        2.3    2.7    1.4    1.3    1.3
# 2     3.4     3.7     3.7    2.7        3.7      4      4      4      4
# 3     1.4     1.0     2.3      1        3.0    1.3    2.7      1      2
# 4     3.4     4.0     3.7      2        4.0      4    3.7    3.7    3.7
#
#   CS-211 CS-203 CS-214  EE-217  CS-212 CS-215  MT-331  EF-303 HS-304  CS-301  \
# ...

# %%
model3.drop(["Seat No."], axis=1, inplace = True)

# %%
model3.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.3     1.4        2.0     1.4     1.3     1.0     1.4     2.7
# 1     4.0     1.0     1.3        1.0     2.7     2.0     1.0     4.0     1.3
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
# 3     1.0     2.3     1.3        1.0     1.0     3.7     1.3     1.4     1.0
# 4     3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4     4.0
#
#    ME-107 CS-107  HS-205/20 MT-222 EE-222 MT-224 CS-210 CS-211 CS-203 CS-214  \
# 0     1.4    1.4        3.4      1    3.7    2.7    2.3    1.3    1.3      1
# 1     1.0    3.4        2.3    2.7    1.4    1.3    1.3      1      2      1
# 2     3.7    2.7        3.7      4      4      4      4      4      4    3.7
# 3     2.3      1        3.0    1.3    2.7      1      2    3.4    2.3      1
# 4     3.7      2        4.0      4    3.7    3.7    3.7    2.7      4    3.7
#
# ...

# %%
import random
def remove_str(nd_array):
    for i in nd_array:
#         new.append(i)
        for j in range(len(i)):
            if type(i[j])==str:
                y=random.uniform(0.0, 4.0)
                x=float("{0:.3f}". format(y))
                i[j] = x
                
#                 new.pop()
#                 y_arr.pop()
    return nd_array


def rounded(array):
    y_train=[]
    for i in range(len(array)):
        x=float("{0:.3f}". format(array[i]))
        y_train.append(x)
    return y_train

# a=[[1,2,'I'],[2,4,5,6],[2,4,5,6],[2,4,5,6],[2,4,5,'W']]
# print(remove_str(a))

# %% [markdown]
# # MODEL-3  ( KNN REGRESSION )

# %%
# Every one line skipped means cell change...(KNN Regression) Model2
y=model3['CGPA'].values
model3.drop(['CGPA'],axis=1,inplace=True)
#model3.drop(['Seat No.'],axis=1,inplace=True)
x=model3.values

# %% [markdown]
# ## Divide the dataset into 75% for training and 25% for testing purpose

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.25 , random_state=25)

# %%
y_train = rounded(y_train)
y_test = rounded(y_test)
x_train = remove_str(x_train)
x_test = remove_str(x_test)

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors=5)
regressor.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# ##  this line is actually predict the output.. overall CGPA based on the current data it has (i-e x_test)

# %%
y_pred = regressor.predict(x_test)
# print(y_pred)
# print(y_test)

# %%
y_pred = rounded(y_pred)

# %%
# y_pred

# %%
sample2=[]
for i in range(1,35):
    inp=float(input('Enter GP of Course'))
    sample2.append(inp)
print(sample2)
ml.predict([sample2])

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ## calculating the accuracy of this model

# %%
accuracy = r2_score(y_test,y_pred)
print("Model Accuracy =", accuracy*100, "in percent")
# Out:
# Model Accuracy = 90.15797263911219 in percent

# %% [markdown]
# ## We use Matplotlib library to show the trend and compare the actual and predicted output :)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %% [markdown]
# # MODEL-3  ( MULTIPLE LINEAR REGRESSION )

# %%
# Every one line skipped means cell change...(Multiple Linear Regression) Model2
y=model3['CGPA'].values
model3.drop(['CGPA'],axis=1,inplace=True)
#model3.drop(['Seat No.'],axis=1,inplace=True)
x=model3.values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.25 , random_state=0)

# %%
y_train = rounded(y_train)
y_test = rounded(y_test)
x_train = remove_str(x_train)
x_test = remove_str(x_test)

# %% [markdown]
# ## applying Linear Regression model here :)

# %%
from sklearn.linear_model import LinearRegression

# %%
ml = LinearRegression()
ml.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = ml.predict(x_test)
# print(y_pred)
# print(y_test)

# %%
y_pred = rounded(y_pred)

# %%
# y_pred

# %%
sample2=[]
for i in range(1,35):
    inp=float(input('Enter GP of Course'))
    sample2.append(inp)
print(sample2)
ml.predict([sample2])

# %%
from sklearn.metrics import r2_score

# %%
accuracy = r2_score(y_test,y_pred)
print("Model Accuracy =", accuracy*100, "in percent")
# Out:
# Model Accuracy = 96.20306607240664 in percent

# %% [markdown]
# ## We use Matplotlib library to show the trend and compare the actual and predicted output :)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %% [markdown]
# # INTERFACE CLI

# %%
def start():
    print('***********************************\nWelcome to CGPA Prediction Platform\n***********************************\n')
    print('This platform can tell your final CGPA based on your current Progressive Transcript\n')
    print('\nYou have to just Enter your those courses  GPA that you have cleared...\n\n')
    
def getinput(x):
    input_array=[]
    for i in range(1,x+1):
        print('Enter GP of Course',i,':',end='')
        inp=float(input())
        input_array.append(inp)
    return input_array

def getoutput(regression,input_array):
    pred=regression.predict(input_array)
    return pred

# %% [markdown]
# ## This is the main CLI cell, which is to be run in order to simulate the project :)

# %%
while True:
    start()
    a = input('Press Enter to continue...')
        
    b= int(input("Choose Your Academic Year..\n1. 1stYear\n2. 2nd Year\n3. 3rd Year"))
    
        #KNN or Multiple Linear Regression Code here
    c =int( input("Choose Model To calculate CGPA\n1. KNN\n2. Multi Linear Regression"))
    if b == 1 and c==1:
        input_array = getinput(11)
        pred = getoutput(regressor,[input_array])
        print('Your Final CGPA is from KNN Regression based on your 1st Year = ', round(pred[0], 3))
        command = int(input('Press 1 or 2\n\n1. Restart the system.\n2.Exit.\n'))
    
        if command == 1:
            continue
        else:
            break
    elif b == 1 and c==2:
        input_array = getinput(11) 
        pred = getoutput(ml,[input_array])
        print('Your Final CGPA is from Multi Linear Regression based on your 1st Year = ', round(pred[0], 3))
        command = int(input('Press 1 or 2\n\n1. Restart the system.\n2.Exit.\n'))
    
        if command == 1:
            continue
        else:
            break
    elif b == 2 and c==1:
        input_array = getinput(22)
        pred = getoutput(regressor,[input_array])
        print('Your Final CGPA is from KNN Regression based on your 2nd Year = ',  round(pred[0], 3))
        command = int(input('Press 1 or 2\n\n1. Restart the system.\n2.Exit.\n'))
    
        if command == 1:
            continue
        else:
            break
    elif b == 2 and c==2:
        input_array = getinput(22)
        pred = getoutput(ml,[input_array])
        print('Your Final CGPA is from Multi Linear Regression based on your 2nd Year = ', round(pred[0], 3))
        command = int(input('Press 1 or 2\n\n1. Restart the system.\n2.Exit.\n'))
    
        if command == 1:
            continue
        else:
            break
    elif b == 3 and c==1:
        input_array = getinput(34)
        pred = getoutput(regressor,[input_array])
        print('Your Final CGPA is from KNN Regression based on your 3rd Year = ', round(pred[0], 3))
        command = int(input('Press 1 or 2\n\n1. Restart the system.\n2.Exit.\n'))
    
        if command == 1:
            continue
        else:
            break
    elif b == 3 and c==2:
        input_array = getinput(34)
        pred = getoutput(ml,[input_array])
        print('Your Final CGPA is from Multi Linear Regression based on your 3rd Year = ',round(pred[0], 3))
        command = int(input('Press 1 or 2\n\n1. Restart the system.\n2.Exit.\n'))
    
        if command == 1:
            continue
        else:
            break
 
    2
#     print('Your Final CGPA is:',pred[0])
    
    command = int(input('Press 1 or 2\n\n1. Restart the system.\n2.Exit.\n'))
    
    if command == 1:
        continue
    else:
        break
# Out:
# ***********************************
# Welcome to CGPA Prediction Platform
# ***********************************
#
# This platform can tell your final CGPA based on your current Progressive Transcript
#
#
# You have to just Enter your those courses  GPA that you have cleared...
#
#
# Press Enter to continue...
# Choose Your Academic Year..
# 1. 1stYear
# 2. 2nd Year
# 3. 3rd Year3
# Choose Model To calculate CGPA
# 1. KNN
# 2. Multi Linear Regression1
# Enter GP of Course 1 :3.2
# Enter GP of Course 2 :3.2
# Enter GP of Course 3 :3.2
# Enter GP of Course 4 :3.2
# Enter GP of Course 5 :3.2
# Enter GP of Course 6 :3.2
# Enter GP of Course 7 :3.2
# Enter GP of Course 8 :3.2
# Enter GP of Course 9 :3.2
# Enter GP of Course 10 :3.2
# Enter GP of Course 11 :3.2
# Enter GP of Course 12 :3.2
# Enter GP of Course 13 :3.2
# Enter GP of Course 14 :3.2
# Enter GP of Course 15 :3.2
# Enter GP of Course 16 :3.2
# Enter GP of Course 17 :3.2
# Enter GP of Course 18 :3.2
# Enter GP of Course 19 :3.2
# ...
